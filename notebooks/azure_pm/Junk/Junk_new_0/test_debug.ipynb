# %%
def add(x, y):
    print("This is good")
    c = x+y
    d= x * y
    f  = c/d
    return f




g = 10
d = 2
res = add(g, d)
print(res)
# Out:
# This is good
# 0.6

# %%
# Out:
# This is good
# 0.6
